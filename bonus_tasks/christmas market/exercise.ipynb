# %% [markdown]
# After you have more or less passed your first class test, you would like to go to the Christmas market with your fellow students and drink some hot wine. Unfortunately, this doesn't seem to be an easy endeavour for such a large group, because a few conditions have to hold for each person p \inp∈ people and each hot wine stand s \ins∈ stands:
#
# Every person pp has an individual budget budget[p] for the evening that they do not want to exceed.
# Students have their individual preferences regarding the hot wine stands and where they want to spend their evening, so each person pp wants to drink a maximum of max_wine_per_stand[p,s] cups of hot wine at stand s \ins∈ stands.
# Every person needs at least min_wine_total[p] cups of hot wine to enjoy the evening. The person should drink at least that much to have fun.
# It is cold and to ensure that no one is freezing, every person needs an average drinking temperature of min_avg_temperature. For a given liquid volume V=\sum_i V_iV=∑
# i
# ​
#  V
# i
# ​
#  , the average temperature of that liquid may be calculated with t^\mathrm{avg} = \left(\sum_i t_i V_i \right)V^{-1}t
# avg
#  =(∑
# i
# ​
#  t
# i
# ​
#  V
# i
# ​
#  )V
# −1
#  , given that the partial volumes V_iV
# i
# ​
#   and corresponding temperatures t_it
# i
# ​
#   are known.
# To ensure that no one is waiting too long without a drink at a stand ss, every person pp can only drink one cup more or less than any other person at the same stand.
# Since RWTH tests different hot wine stands every year, the data sets are already given. For every s \ins∈stands we already know:
#
# temperature[s]: The temperature of the hot wine in degrees Celsius
# amount[s]: The amount of hot wine per cup in milliliter
# alcohol_content[s]: The amount of alcohol in % by volume
# sugar[s]: The amount of sugar in milligrams per liter
# calorific_value[s]: The calorific value in kcal per 200 milliliters
# price[s]: Price per cup
# cup_type[s]: Cup type
# The goal is to model the problem as an integer program (IP) so that the total money paid for hot wine is minimized. The decision variable x_{p,s} \in \mathbb{N}_0 ~ \forall ~ p \inx
# p,s
# ​
#  ∈N
# 0
# ​
#   ∀ p∈ people ~\forall ~ s \in ∀ s∈ stands specifies how much hot wine in cups a person pp drinks at ss.
#
# You are given the files christmas_market.py, christmas_market-2018.py and christmas_market-2019.py. Complete the code in christmas_market.py to find an optimal solution to the hot wine problem that meets the given conditions.
#
# Model the problem as an integer linear program and add the missing constraint to the file christmas_market.py so that the hot wine problem is solved. If necessary, add attributes for the given decision variables (e.g. lb, ub, obj, vtype) in the given model. You can (partially) test your model by executing the code in christmas_market-2018.py or christmas_market-2019.py. The solve() function you completed will be called from christmas_market.py.
#
# Add comments at the places where you complete christmas_market.py, specifying what the corresponding lines mean. This increases the understanding of your model in case of wrong evaluations and makes it easier for you to keep track of more complicated models.
#
# The data sets for hot wine are all real data sets. So feel free to play around with them and model your own problems, like a traveling sales person problem (TSP).
#
# Hints:
#
# The files christmas_market-2018.py and christmas_market-2019.py shall not be modified, only add to the file christmas_market.py.
# In order to test your model, the files christmas_market-2018.py and christmas_market-2019.py have to be saved in the same directory as the file christmas_market.py.
# First write down the model on paper, and implement it if you are certain that it is correct.
# Please keep in mind to create a linear model. If you multiply different variables with each other, this will result in 0 points.
# The optimal objective value is 81.481.4 for christmas_market-2018.py and 102102 for christmas_market-2019.py.
# You can add additional variables, but the given variables have to be used and must not be renamed, otherwise you will receive 0 points.
# Please keep in mind that the problem has to be modeled correctly. It is not enough if your model just returns the correct objective values for the test instances.
# If you have questions, do not hesitate to ask in the forum or on the internet. Good luck!
# Technische Voraussetzungen
# Ihr Code sollte unter der Pythonversion 3.6.6 ausführbar sein.
# Ihr Code sollte mit Gurobi 9.1.2 ausführbar sein.
# Sie dürfen nur gurobipy importieren.
# Sie dürfen eval und exec nicht verwenden.
# Sie dürfen höchstens eine Datei hochladen.
# Die maximale Dateigröße beträgt 1 MB.
# Ihre Dateien dürfen nur die Dateiendung .py haben.
# Stellen Sie sicher, dass Sie eine Datei mit dem Namen christmas_market.py hochladen.
# Ändern Sie nicht die Namen der Variablen, die bereits im Gurobi-Modell definiert sind. Verwenden Sie, wenn Sie neue Variablen deklarieren, nicht schon vorhandene Namen.
# Die Verwendung des Bitshift- oder Implikationsoperators ist nicht erlaubt.
